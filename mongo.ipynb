# %% [raw]
# mongodb+srv://rabbishakir:FreshImpact69@#@gemini-bot-0.mv8vq6l.mongodb.net/?appName=gemini-bot-0
# project->cluster->db->collection

# %%
import pandas as pd

data = pd.read_csv('userdata.csv')
type(data)
data_dic = data.to_dict(orient='records')

# %%
import pymongo
from urllib.parse import quote_plus

# Database and collection names
DB_NAME = "geminiBotDB"
COLLECTION_NAME = "geminiBotCollection"

# Your credentials
username = "rabbishakir"
password = "jqAi5pC7MpcWTY9q"

# Escape the credentials
escaped_username = quote_plus(username)
escaped_password = quote_plus(password)

# Build the connection URL with escaped credentials and your actual cluster address
CONNECTION_URL = f"mongodb+srv://{escaped_username}:{escaped_password}@gemini-bot-0.mv8vq6l.mongodb.net/?retryWrites=true&w=majority&appName=gemini-bot-0"

# Now connect
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]

collection = data_base[COLLECTION_NAME]

#storing data to mongodb database
rec = collection.find()
print(rec)
